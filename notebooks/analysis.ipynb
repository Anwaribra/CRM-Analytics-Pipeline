# %%
import pandas as pd
import psycopg2

# %%
conn = psycopg2.connect(
    dbname='crm_db',
    user='postgres',
    password='2003',
    host='localhost',
    port='5432'
)

# %%
df = pd.read_sql("SELECT * FROM contacts", conn)
print(df.info())
df.head()
# Out:
# /tmp/ipykernel_89387/1922346233.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM contacts", conn)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                100000 non-null  object
#  1   createdate        100000 non-null  datetime64[ns]
#  2   email             100000 non-null  object
#  3   firstname         100000 non-null  object
#  4   lastname          100000 non-null  object
#  5   hs_object_id      100000 non-null  object
#  6   lastmodifieddate  100000 non-null  datetime64[ns]
#  7   archived          100000 non-null  bool
# dtypes: bool(1), datetime64[ns](2), object(5)
# memory usage: 5.4+ MB
# None
# ...
